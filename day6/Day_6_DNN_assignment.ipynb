# %% [markdown]
# ## DNN Example for Fashion MNIST Dataset

# %%
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization,Dropout

from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## ResNet (DNN) Example for Fashion MNIST Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add, Activation, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Flatten the images for DNN
x_train_flat = x_train.reshape(-1, 28*28)
x_test_flat = x_test.reshape(-1, 28*28)

# Visualize some samples
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
# Standard DNN Model
def create_dnn():
    inputs = Input(shape=(784,))
    x = Dense(512, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)


    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.1)(x)

    outputs = Dense(10, activation='softmax')(x)
    return Model(inputs, outputs)

# ResNet-style DNN Model (with residual connections)


def create_resnet_dnn():
    inputs = Input(shape=(784,))
    
    # Initial dense layer
    x = Dense(256)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.4)(x)

    # Residual block 1
    x1 = Dense(256)(x)
    x1 = BatchNormalization()(x1)
    x1 = Activation('relu')(x1)
    x1 = Dropout(0.4)(x1)

    x2 = Dense(256)(x1)
    x2 = BatchNormalization()(x2)

    res1 = Add()([x, x2])
    res1 = Activation('relu')(res1)
    res1 = Dropout(0.3)(res1)

    # Residual block 2
    x3 = Dense(128)(res1)
    x3 = BatchNormalization()(x3)
    x3 = Activation('relu')(x3)
    x3 = Dropout(0.2)(x3)

    x4 = Dense(128)(x3)
    x4 = BatchNormalization()(x4)

    res1_proj = Dense(128)(res1)
    res2 = Add()([res1_proj, x4])
    res2 = Activation('relu')(res2)
    res2 = Dropout(0.1)(res2)

    # **New Residual block 3**
    x5 = Dense(128)(res2)
    x5 = BatchNormalization()(x5)
    x5 = Activation('relu')(x5)
    x5 = Dropout(0.2)(x5)

    x6 = Dense(128)(x5)
    x6 = BatchNormalization()(x6)

    res2_proj = Dense(128)(res2)
    res3 = Add()([res2_proj, x6])
    res3 = Activation('relu')(res3)
    res3 = Dropout(0.1)(res3)

    # **New Residual block 4**
    x7 = Dense(64)(res3)
    x7 = BatchNormalization()(x7)
    x7 = Activation('relu')(x7)
    x7 = Dropout(0.1)(x7)

    x8 = Dense(64)(x7)
    x8 = BatchNormalization()(x8)

    res3_proj = Dense(64)(res3)
    res4 = Add()([res3_proj, x8])
    res4 = Activation('relu')(res4)
    res4 = Dropout(0.1)(res4)

    # Final layers
    x_final = Dense(64, activation='relu')(res4)
    x_final = BatchNormalization()(x_final)
    outputs = Dense(10, activation='softmax')(x_final)
    
    return Model(inputs, outputs)

# %%
# Create and compile models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

dnn_model = create_dnn()
resnet_model = create_resnet_dnn()
early = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

dnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
resnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'],)

# %%
# Train models
dnn_history = dnn_model.fit(x_train_flat, y_train, 
                            epochs=50, 
                            batch_size=256, 
                            validation_split=0.1,
                           callbacks=[early, lr_reduce],

                            verbose=1)

resnet_history = resnet_model.fit(x_train_flat, y_train, 
                                 epochs=50, 
                                 batch_size=256, 
                                 validation_split=0.1,
                                  callbacks=[early, lr_reduce],
                                 verbose=1)
# Out:
# Epoch 1/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9015 - loss: 0.2760 - val_accuracy: 0.8893 - val_loss: 0.3133 - learning_rate: 6.2500e-05
# Epoch 2/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.9019 - loss: 0.2731 - val_accuracy: 0.8915 - val_loss: 0.3061 - learning_rate: 6.2500e-05
# Epoch 3/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9021 - loss: 0.2731 - val_accuracy: 0.8907 - val_loss: 0.3078 - learning_rate: 6.2500e-05
# Epoch 4/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8994 - loss: 0.2769 - val_accuracy: 0.8905 - val_loss: 0.3063 - learning_rate: 6.2500e-05
# Epoch 5/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9001 - loss: 0.2728 - val_accuracy: 0.8913 - val_loss: 0.3057 - learning_rate: 6.2500e-05
# Epoch 6/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9019 - loss: 0.2747 - val_accuracy: 0.8907 - val_loss: 0.3061 - learning_rate: 6.2500e-05
# Epoch 7/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9024 - loss: 0.2660 - val_accuracy: 0.8898 - val_loss: 0.3091 - learning_rate: 6.2500e-05
# Epoch 8/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9017 - loss: 0.2712
# Epoch 8: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9017 - loss: 0.2712 - val_accuracy: 0.8905 - val_loss: 0.3068 - learning_rate: 6.2500e-05
# Epoch 9/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9020 - loss: 0.2720 - val_accuracy: 0.8918 - val_loss: 0.3055 - learning_rate: 3.1250e-05
# Epoch 10/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9032 - loss: 0.2681 - val_accuracy: 0.8920 - val_loss: 0.3055 - learning_rate: 3.1250e-05
# Epoch 11/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9051 - loss: 0.2626 - val_accuracy: 0.8932 - val_loss: 0.3052 - learning_rate: 3.1250e-05
# Epoch 12/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9048 - loss: 0.2662 - val_accuracy: 0.8922 - val_loss: 0.3062 - learning_rate: 3.1250e-05
# Epoch 13/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9033 - loss: 0.2656 - val_accuracy: 0.8923 - val_loss: 0.3056 - learning_rate: 3.1250e-05
# Epoch 14/50
# 210/211 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9075 - loss: 0.2595
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9075 - loss: 0.2595 - val_accuracy: 0.8935 - val_loss: 0.3052 - learning_rate: 3.1250e-05
# Epoch 15/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9009 - loss: 0.2692 - val_accuracy: 0.8923 - val_loss: 0.3056 - learning_rate: 1.5625e-05
# Epoch 16/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9080 - loss: 0.2586 - val_accuracy: 0.8933 - val_loss: 0.3052 - learning_rate: 1.5625e-05
# Epoch 17/50
# 210/211 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9062 - loss: 0.2615
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.9062 - loss: 0.2615 - val_accuracy: 0.8933 - val_loss: 0.3056 - learning_rate: 1.5625e-05
# Epoch 18/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9051 - loss: 0.2620 - val_accuracy: 0.8930 - val_loss: 0.3050 - learning_rate: 7.8125e-06
# Epoch 19/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9061 - loss: 0.2598 - val_accuracy: 0.8930 - val_loss: 0.3059 - learning_rate: 7.8125e-06
# Epoch 20/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9077 - loss: 0.2611 - val_accuracy: 0.8937 - val_loss: 0.3057 - learning_rate: 7.8125e-06
# Epoch 21/50
# 210/211 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9047 - loss: 0.2593
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9048 - loss: 0.2593 - val_accuracy: 0.8935 - val_loss: 0.3055 - learning_rate: 7.8125e-06
# Epoch 22/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.9046 - loss: 0.2639 - val_accuracy: 0.8942 - val_loss: 0.3057 - learning_rate: 3.9063e-06
# Epoch 23/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9071 - loss: 0.2621 - val_accuracy: 0.8935 - val_loss: 0.3057 - learning_rate: 3.9063e-06
# Epoch 1/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9052 - loss: 0.2672 - val_accuracy: 0.8923 - val_loss: 0.3163 - learning_rate: 2.5000e-04
# Epoch 2/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9066 - loss: 0.2547 - val_accuracy: 0.8907 - val_loss: 0.3129 - learning_rate: 2.5000e-04
# Epoch 3/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9104 - loss: 0.2496 - val_accuracy: 0.8907 - val_loss: 0.3095 - learning_rate: 2.5000e-04
# Epoch 4/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9123 - loss: 0.2469 - val_accuracy: 0.8948 - val_loss: 0.3075 - learning_rate: 2.5000e-04
# Epoch 5/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9128 - loss: 0.2454 - val_accuracy: 0.8913 - val_loss: 0.3276 - learning_rate: 2.5000e-04
# Epoch 6/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.9135 - loss: 0.2432 - val_accuracy: 0.8955 - val_loss: 0.3076 - learning_rate: 2.5000e-04
# Epoch 7/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9131 - loss: 0.2452
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.9131 - loss: 0.2452 - val_accuracy: 0.8920 - val_loss: 0.3159 - learning_rate: 2.5000e-04
# Epoch 8/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9167 - loss: 0.2357 - val_accuracy: 0.8985 - val_loss: 0.3125 - learning_rate: 1.2500e-04
# Epoch 9/50
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9177 - loss: 0.2318 - val_accuracy: 0.8962 - val_loss: 0.3142 - learning_rate: 1.2500e-04

# %%
# Plot training history
def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    plt.suptitle(title)
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    
    plt.show()

# %%
plot_history(dnn_history, 'Standard DNN Training')
plot_history(resnet_history, 'ResNet-style DNN Training')

# %%
# Evaluate on test set
dnn_test_loss, dnn_test_acc = dnn_model.evaluate(x_test_flat, y_test, verbose=0)
resnet_test_loss, resnet_test_acc = resnet_model.evaluate(x_test_flat, y_test, verbose=0)

# %%
print(f"Standard DNN Test Accuracy: {dnn_test_acc:.4f}")
print(f"ResNet-style DNN Test Accuracy: {resnet_test_acc:.4f}")
# Out:
# Standard DNN Test Accuracy: 0.8874
# ResNet-style DNN Test Accuracy: 0.8983

# %%
# Make predictions and visualize some results
def plot_predictions(model, x_test, y_test, num_images=5):
    predictions = model.predict(x_test)
    plt.figure(figsize=(15, 3*num_images))
    for i in range(num_images):
        plt.subplot(num_images, 1, i+1)
        plt.imshow(x_test[i].reshape(28, 28), cmap=plt.cm.binary)
        pred_label = np.argmax(predictions[i])
        true_label = np.argmax(y_test[i])
        color = 'green' if pred_label == true_label else 'red'
        plt.xlabel(f"Predicted: {class_names[pred_label]} (True: {class_names[true_label]})", color=color)
    plt.show()

print("\nStandard DNN Predictions:")
plot_predictions(dnn_model, x_test_flat, y_test)

print("\nResNet-style DNN Predictions:")
plot_predictions(resnet_model, x_test_flat, y_test)
# Out:
# Standard DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ResNet-style DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
